# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

df = pd.read_csv("raman_data.CSV")
df
# Out:
#              X    Y       X.1  Y.1       X.2   Y.2       X.3   Y.3
# 0      -88.705  374   -90.458  390   -90.458   362   -87.593   338
# 1      -86.418  435   -88.169  371   -88.169   357   -85.306   335
# 2      -84.131  470   -85.881  400   -85.881   400   -83.020   398
# 3      -81.844  482   -83.594  348   -83.594   364   -80.734   390
# 4      -79.559  456   -81.307  380   -81.307   412   -78.449   374
# ...        ...  ...       ...  ...       ...   ...       ...   ...
# 1926  3312.465  555  3312.057  349  3312.057  3443  3313.190  1347
# 1927  3313.765  547  3313.355  366  3313.355  3159  3314.491  1172
# 1928  3315.064  550  3314.654  361  3314.654  3208  3315.791  1302
# 1929  3316.362  540  3315.952  390  3315.952  3347  3317.092  1220
# 1930  3317.660  548  3317.249  357  3317.249  3316  3318.392  1375
#
# [1931 rows x 8 columns]

# %%
df_filter1 = df[df["X"] > 20]

x = np.array(df_filter1["X"].tolist())
y = np.array(df_filter1["Y"].tolist())

peak, _ = find_peaks(y,distance=5)

plt.axvline(x=x[peak][0],color='g',linestyle='--', linewidth=1,label="RGO, "+str(x[peak][0]))
plt.plot(x,y,color='g')

df_filter2 = df[df["X.1"] > 15]
x2 = np.array(df_filter2["X.1"].tolist())
y2 = np.array(df_filter2["Y.1"].tolist())

peak2, _ = find_peaks(y2,distance=5)
plt.axvline(x=x2[peak2][1],color='r',linestyle='-', linewidth=1,label="Graphite, "+str(x2[peak2][1]))
plt.plot(x2,y2,color='r')

df_filter3 = df[df["X.2"] > 30]
x3 = np.array(df_filter3["X.2"].tolist())
y3 = np.array(df_filter3["Y.2"].tolist())

peak3, _ = find_peaks(y3,distance=5)
plt.axvline(x=x3[peak3][0],color='b',linestyle='--', linewidth=1, label="GO, "+str(x3[peak3][0]))
plt.plot(x3,y3,color='b')


plt.xlim(10,100)
plt.ylim(0,20000)
plt.ylabel("Intensity")
plt.xlabel("Raman Shift[1/cm]")
plt.legend()

plt.savefig('cpeak.png', facecolor='#eeeeee',
            bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
"""
df_filter2 = df[df["X.1"] > 15]
x2 = np.array(df_filter2["X.1"].tolist())
y2 = np.array(df_filter2["Y.1"].tolist())

peak2, _ = find_peaks(y2,distance=10)
#plt.plot(x2[peak2], y2[peak2], 'ro')
plt.axvline(x=x2[peak2][0],color='r',linestyle='--', linewidth=1,label=str(x2[peak2][0]))
plt.plot(x2,y2)

plt.ylabel("Intensity")
plt.xlabel("Raman Shift[1/cm]")
plt.title("Graphite")
plt.legend()
plt.savefig('gr_.png', facecolor='#eeeeee',
            bbox_inches='tight', pad_inches=0.3)
plt.show()
"""
# Out:
# '\ndf_filter2 = df[df["X.1"] > 15]\nx2 = np.array(df_filter2["X.1"].tolist())\ny2 = np.array(df_filter2["Y.1"].tolist())\n\npeak2, _ = find_peaks(y2,distance=10)\n#plt.plot(x2[peak2], y2[peak2], \'ro\')\nplt.axvline(x=x2[peak2][0],color=\'r\',linestyle=\'--\', linewidth=1,label=str(x2[peak2][0]))\nplt.plot(x2,y2)\n\nplt.ylabel("Intensity")\nplt.xlabel("Raman Shift[1/cm]")\nplt.title("Graphite")\nplt.legend()\nplt.savefig(\'gr_.png\', facecolor=\'#eeeeee\',\n            bbox_inches=\'tight\', pad_inches=0.3)\nplt.show()\n'

# %%
"""
df_filter3 = df[df["X.2"] > 30]
x3 = np.array(df_filter3["X.2"].tolist())
y3 = np.array(df_filter3["Y.2"].tolist())

peak3, _ = find_peaks(y3, height=1000,distance=50)
plt.axvline(x=x3[peak3][0],color='r',linestyle='--', linewidth=1, label=str(x3[peak3][0]))
plt.axvline(x=x3[peak3][1],color='g',linestyle='--', linewidth=1, label=str(x3[peak3][1]))
plt.plot(x3,y3)
plt.xlim(0,1000)
plt.title("Graphene Oxide")
plt.ylabel("Intensity")
plt.xlabel("Raman Shift[1/cm]")
plt.legend()
plt.savefig('go_.png', facecolor='#eeeeee',
            bbox_inches='tight', pad_inches=0.3)
plt.show()
"""
# Out:
# '\ndf_filter3 = df[df["X.2"] > 30]\nx3 = np.array(df_filter3["X.2"].tolist())\ny3 = np.array(df_filter3["Y.2"].tolist())\n\npeak3, _ = find_peaks(y3, height=1000,distance=50)\nplt.axvline(x=x3[peak3][0],color=\'r\',linestyle=\'--\', linewidth=1, label=str(x3[peak3][0]))\nplt.axvline(x=x3[peak3][1],color=\'g\',linestyle=\'--\', linewidth=1, label=str(x3[peak3][1]))\nplt.plot(x3,y3)\nplt.xlim(0,1000)\nplt.title("Graphene Oxide")\nplt.ylabel("Intensity")\nplt.xlabel("Raman Shift[1/cm]")\nplt.legend()\nplt.savefig(\'go_.png\', facecolor=\'#eeeeee\',\n            bbox_inches=\'tight\', pad_inches=0.3)\nplt.show()\n'

# %%
rgo_x = np.array(df_filter3["X"].tolist())
rgo_y = np.array(df_filter3["Y"].tolist())
gr_x = np.array(df_filter3["X.1"].tolist())
gr_y = np.array(df_filter3["Y.1"].tolist())
go_x = np.array(df_filter3["X.2"].tolist())
go_y = np.array(df_filter3["Y.2"].tolist())

plt.plot(rgo_x,rgo_y,label='RGO')
plt.plot(gr_x,gr_y,label='GR')
plt.plot(go_x,go_y,label='GO')

plt.axvline(x=1580,color='r',linestyle='--', linewidth=1)
plt.axvline(x=1350,color='r',linestyle='--', linewidth=1)
plt.axvline(x=2710,color='r',linestyle='--', linewidth=1)
plt.axvline(x=2910,color='r',linestyle='--', linewidth=1)

plt.text(1570,36000,"1580",weight='bold',color='r',ha='right',rotation=90)
plt.text(1560,42000,"G",weight='bold',ha='right',size=12)
plt.text(1340,36000,"1350",weight='bold',color='r',ha='right',rotation=90)
plt.text(1330,42000,"D",weight='bold',ha='right',size=12)
plt.text(2700,36000,"2710",weight='bold',color='r',ha='right',rotation=90)
plt.text(2700,42000,"2D",weight='bold',ha='right',size=12)
plt.text(2900,36000,"2910",weight='bold',color='r',ha='right',rotation=90)
plt.text(2950,42000,"D+D'",weight='bold',ha='center',size=12)

plt.ylim(0,45000)
plt.ylabel("Intensity",size=12)
plt.xlabel("Raman Shift[1/cm]",size=12)
plt.legend()
plt.savefig('graphene_vibration mode.png', facecolor='#eeeeee',
            bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
df_filter4 = df[df["X.3"] > 10]
x4 = np.array(df_filter4["X.3"].tolist())
y4 = np.array(df_filter4["Y.3"].tolist())

peak4, _ = find_peaks(y4, height=9000, width=10)
plt.axvline(x=x4[peak4][0],color='r',linestyle='--', linewidth=1, label=str(x4[peak4][0]))
plt.axvline(x=x4[peak4][1],color='g',linestyle='--', linewidth=1, label=str(x4[peak4][1]))
plt.axvline(x=x4[peak4][2],color='m',linestyle='--', linewidth=1, label=str(x4[peak4][2]))
plt.axvline(x=x4[peak4][3],color='y',linestyle='--', linewidth=1, label=str(x4[peak4][3]))
plt.axvline(x=x4[peak4][5],color='c',linestyle='--', linewidth=1, label=str(x4[peak4][5]))

plt.text(250,32000,"ω1",weight='bold',ha='center',size=12)
plt.text(434,51000,"ω2",weight='bold',ha='center',size=12)
plt.text(608,47000,"ω3",weight='bold',ha='center',size=12)
plt.text(1341,12000,"D",weight='bold',ha='center',size=12)
plt.text(1579,12000,"G",weight='bold',ha='center',size=12)

plt.plot(x4,y4)

plt.ylim(0,55000)

plt.ylabel("Intensity",size=12)
plt.xlabel("Raman Shift[1/cm]",size=12)
plt.legend()
plt.savefig('Ti2Ctx.png', facecolor='#eeeeee',
            bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(df["X"],df["Y"])
plt.show()

# %%
plt.plot(df["X.1"],df["Y.1"])
plt.show()

# %%
plt.plot(df["X.2"],df["Y.2"])
plt.show()

# %%
plt.plot(df["X.3"],df["Y.3"])
plt.show()

# %%
#LASER=532
#IT=0ms
#XUNITS=1/cm
#LEN=1931
